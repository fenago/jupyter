# %% [markdown]
# ## Installing Packages
#     1. Pandas
#     2. Requests
#     3. Pandasql

# %%
! pip install pandas requests pandasql
# Out:
# Requirement already satisfied: pandas in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (1.3.5)
# Requirement already satisfied: requests in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (2.28.1)
# Requirement already satisfied: pandasql in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (0.7.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from pandas) (1.21.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from requests) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from requests) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from requests) (2022.6.15.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: sqlalchemy in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from pandasql) (1.4.41)
# Requirement already satisfied: six>=1.5 in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from sqlalchemy->pandasql) (1.1.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from sqlalchemy->pandasql) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy->pandasql) (4.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\rahul.jha\desktop\fl\fl\lib\site-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy->pandasql) (3.8.1)
# You are using pip version 19.0.3, however version 22.2.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Importing the packages

# %%
import requests
import pandas as pd
from pandasql import sqldf

# %% [markdown]
# ## Creating a function to compute age:
#
# This link https://www.hockey-reference.com/about/glossary.html explains that for each season, the age
# of the player should be calculated from the birthdate till jan 31 of the season year.
#
# So, here we are creating a function called get_age which takes season and birthday as the string
# in the following forms:
#
#     1. season = 20212022
#     2. birthday = "1985-01-23"
#
# So, we create two datetime objects for season (with jan 31 as the base date) and for the birthday.
#
# We just compute the differencere between these two to get the age.

# %%
from datetime import datetime

def get_age(season, birthday):
    season_end_age = season[:4] + "-01" + "-31"
    current_time = datetime.strptime(season_end_age, "%Y-%m-%d")
    bday = datetime.strptime(birthday, "%Y-%m-%d")

    diff = current_time - bday
    
    age_years = diff.days // 365
    age_days = diff.days % 365
    
    frac = age_days / 365
    final_age = age_years + frac
    return final_age

# %% [markdown]
# ## Function.1 Create_panthers_players_table
#
# So, here the idea is "that we will be getting the data using an open API which is provided by
# the NFL. Every API has something known as endpoint (just a fancy way of saying URL).
#
# This api's base URL looks something like this: https://statsapi.web.nhl.com/api/v1
#
# Now, there are various endpoints such as:
#
#     1. https://statsapi.web.nhl.com/api/v1/teams
#     2. https://statsapi.web.nhl.com/api/v1/people
#     3. https://statsapi.web.nhl.com/api/v1/game
#     4. https://statsapi.web.nhl.com/api/v1/schedule
#
# For this function, we are just going to need **teams** and **people** endpoint.
#
# First we created a list of seasons and then in a loop extracting the data for each season. We do the following for each season:
#
#         1. We append the season to the base link for teams and we also filter for only
#            florida panthers data by giving the floarida team id = 13.
#         2. We get the json of the of the created link using the requests package.
#         3. Then, extract the players which is stored in the roster key
#         4. We then loop through each player and store the basic info and their height and weight
#         from the dictionary objects
#         5. In the inside loop, we also use the get_age function which we created earlier.
#         6. Finally, we create a subset data frame and keep on appending it to the base one.
#         7. and after the loop ends, we return the dataframe.

# %%
def create_panthers_players_table():

    seasons = ["20142015", "20152016", "20162017", "20172018", "20182019",
              "20192020","20202021", "20212022"]
    roster_link = "https://statsapi.web.nhl.com/api/v1/teams?expand=team.roster&season="
    florida_team_id = 13

    panthers_players_table = pd.DataFrame()

    for season in seasons:
        print("Querying data for season = ", season)
        current_roster = requests.get(roster_link + season + "&teamId=" + str(florida_team_id))
        current_roster = current_roster.json()

        list_of_players = current_roster["teams"][0]["roster"]["roster"]

        for player in list_of_players:
            current_id = player["person"]["id"]

            player_info_link = "https://statsapi.web.nhl.com/api/v1/people/"+str(current_id)
            player_stats_link = "https://statsapi.web.nhl.com/api/v1/people/" + str(current_id) + "/stats?stats=statsSingleSeason&season="+season

            player_info = requests.get(player_info_link).json()
            player_stats = requests.get(player_stats_link).json()

            height = player_info["people"][0]["height"]
            weight = player_info["people"][0]["height"]
            birthday = player_info["people"][0]["birthDate"]

            player_stats = player_stats["stats"][0]["splits"]
            if len(player_stats) == 0:
                print(2+2)
            else:
                player_stats = player_stats[0]["stat"]
                age = get_age(season, birthday)


                keys = ["id", "season", "height", "weight", "age"] + list(player_stats.keys())
                values = [current_id, season, height, weight, age] + list(player_stats.values())

                current_data = pd.DataFrame([values], columns = keys)
                panthers_players_table = pd.concat((panthers_players_table, current_data))
    panthers_players_table.reset_index(inplace = True, drop = True)
    return panthers_players_table

# %% [markdown]
# ## Call the function and Save the data
#
# Here, we are calling the function we just created and saving it as csv.

# %%
panthers_players_table = create_panthers_players_table()
panthers_players_table.to_csv("panthers_players_table.csv", index = False)
# Out:
# Querying data for season =  20142015
# Querying data for season =  20152016
# Querying data for season =  20162017
# Querying data for season =  20172018
# Querying data for season =  20182019
# Querying data for season =  20192020
# 4
# Querying data for season =  20202021
# Querying data for season =  20212022

# %% [markdown]
# ## Function.2 create_panthers_game_boxscores_table
#
# The process is just mostly same as the previous one. We loop through the seasons and get the
# appropriate keys from the jsons.

# %%
def create_panthers_game_boxscores_table():
    seasons = ["20142015", "20152016", "20162017", "20172018", "20182019",
               "20192020","20202021", "20212022"]

    df = pd.DataFrame()

    for season in seasons:
        print("Querying data for season = ", season)
        link = f"https://statsapi.web.nhl.com/api/v1/schedule?season={season}&teamId=13"
        json = requests.get(link).json()
        list_of_matches = json["dates"]
        for match in list_of_matches:
            game_id = match["games"][0]["gamePk"]
            h_or_a = match["games"][0]["teams"]["away"]["team"]["id"]
            home_or_away = "away" if h_or_a == 13 else "home"
            game_link = f"https://statsapi.web.nhl.com/api/v1/game/{game_id}/boxscore"
            game_stats = requests.get(game_link).json()

            panthers_stats = game_stats["teams"][home_or_away]["teamStats"]["teamSkaterStats"]
            oppo_h_or_a = "home" if home_or_away == "away" else "home"
            opponent_stats = game_stats["teams"][oppo_h_or_a]["teamStats"]["teamSkaterStats"]

            overall_stats_dict = {"panthers_"+key:[value] for key,value in panthers_stats.items()}

            overall_stats_dict.update({"opponent_"+key:[value] for key,value in opponent_stats.items()})


            final_Dict = {"game_id":[game_id], "HomeOrAway":[home_or_away]}
            final_Dict.update(overall_stats_dict)  

            subset_df = pd.DataFrame(final_Dict)
            df = pd.concat((df, subset_df))
    df.reset_index(inplace = True, drop = True)
    return df

# %% [markdown]
# ## Call the function and Save the data
#
# Here, we are calling the function we just created and saving it as csv.

# %%
panthers_game_boxscores = create_panthers_game_boxscores_table()
panthers_game_boxscores.to_csv("panthers_game_boxscores.csv", index = False)
# Out:
# Querying data for season =  20142015
# Querying data for season =  20152016
# Querying data for season =  20162017
# Querying data for season =  20172018
# Querying data for season =  20182019
# Querying data for season =  20192020
# Querying data for season =  20202021
# Querying data for season =  20212022

# %% [markdown]
# ## Function.3 create_panthers_player_boxscores_table

# %%
def create_panthers_player_boxscores_table():
    d = pd.read_csv("panthers_game_boxscores.csv")
    
    game_ids = d.game_id.values
    home_or_away = d.HomeOrAway.values

    panthers_player_boxscores_table = pd.DataFrame()

    for i,g_id in enumerate(game_ids):
        print("Getting data for game id = ", g_id)
        current_link = f"https://statsapi.web.nhl.com/api/v1/game/{g_id}/boxscore"
        json = requests.get(current_link).json()
        players = json["teams"][home_or_away[i]]["players"].keys()

        for player_id in players:
            curr_player = json["teams"][home_or_away[i]]["players"][player_id]
            stats = curr_player["stats"]

            dict_to_update = {"game_id":[g_id], "player_id":[player_id]}
            if len(stats.keys()) == 0:
                pass
            else:
                keys_of_stats = stats.keys()
                final_stats = {}
                for k in keys_of_stats:
                    new_stats = stats[k]
                    final_stats.update({k + "_" + ke:[va] for ke,va in new_stats.items()})

                dict_to_update.update(final_stats)
                subset_df = pd.DataFrame(dict_to_update)
                panthers_player_boxscores_table = pd.concat((panthers_player_boxscores_table, subset_df))
    panthers_player_boxscores_table.reset_index(inplace=True, drop = True)
    return panthers_player_boxscores_table

# %% [markdown]
# ## Call the function and Save the data
#
# Here, we are calling the function we just created and saving it as csv.

# %%
panthers_players_boxscores = create_panthers_player_boxscores_table()
panthers_players_boxscores.to_csv("panthers_players_boxscores.csv", index = False)
# Out:
# Getting data for game id =  2014010029
# Getting data for game id =  2014010051
# Getting data for game id =  2014010065
# Getting data for game id =  2014010088
# Getting data for game id =  2014010100
# Getting data for game id =  2014020010
# Getting data for game id =  2014020022
# Getting data for game id =  2014020037
# Getting data for game id =  2014020056
# Getting data for game id =  2014020069
# Getting data for game id =  2014020087
# Getting data for game id =  2014020115
# Getting data for game id =  2014020143
# Getting data for game id =  2014020156
# Getting data for game id =  2014020172
# Getting data for game id =  2014020188
# Getting data for game id =  2014020202
# Getting data for game id =  2014020225
# Getting data for game id =  2014020246
# Getting data for game id =  2014020264
# Getting data for game id =  2014020277
# Getting data for game id =  2014020290
# Getting data for game id =  2014020302
# Getting data for game id =  2014020315
# Getting data for game id =  2014020327
# Getting data for game id =  2014020341
# Getting data for game id =  2014020358
# Getting data for game id =  2014020368
# Getting data for game id =  2014020382
# Getting data for game id =  2014020395
# Getting data for game id =  2014020408
# Getting data for game id =  2014020433
# Getting data for game id =  2014020437
# Getting data for game id =  2014020457
# Getting data for game id =  2014020467
# Getting data for game id =  2014020485
# Getting data for game id =  2014020499
# Getting data for game id =  2014020527
# Getting data for game id =  2014020541
# Getting data for game id =  2014020551
# Getting data for game id =  2014020558
# Getting data for game id =  2014020577
# Getting data for game id =  2014020606
# Getting data for game id =  2014020611
# Getting data for game id =  2014020624
# Getting data for game id =  2014020637
# Getting data for game id =  2014020649
# Getting data for game id =  2014020666
# Getting data for game id =  2014020678
# Getting data for game id =  2014020703
# Getting data for game id =  2014020717
# Getting data for game id =  2014020731
# Getting data for game id =  2014020742
# Getting data for game id =  2014020746
# Getting data for game id =  2014020762
# Getting data for game id =  2014020785
# Getting data for game id =  2014020802
# Getting data for game id =  2014020815
# Getting data for game id =  2014020820
# Getting data for game id =  2014020834
# Getting data for game id =  2014020850
# Getting data for game id =  2014020864
# Getting data for game id =  2014020877
# Getting data for game id =  2014020888
# Getting data for game id =  2014020903
# Getting data for game id =  2014020912
# Getting data for game id =  2014020923
# Getting data for game id =  2014020934
# Getting data for game id =  2014020946
# Getting data for game id =  2014020960
# Getting data for game id =  2014020973
# Getting data for game id =  2014021007
# Getting data for game id =  2014021024
# Getting data for game id =  2014021030
# Getting data for game id =  2014021044
# Getting data for game id =  2014021056
# Getting data for game id =  2014021071
# Getting data for game id =  2014021095
# Getting data for game id =  2014021106
# Getting data for game id =  2014021122
# Getting data for game id =  2014021129
# Getting data for game id =  2014021142
# Getting data for game id =  2014021157
# Getting data for game id =  2014021172
# Getting data for game id =  2014021181
# Getting data for game id =  2014021207
# Getting data for game id =  2014021222
# Getting data for game id =  2015010002
# Getting data for game id =  2015010020
# Getting data for game id =  2015010046
# Getting data for game id =  2015010062
# Getting data for game id =  2015010099
# Getting data for game id =  2015020020
# Getting data for game id =  2015020035
# Getting data for game id =  2015020041
# Getting data for game id =  2015020055
# Getting data for game id =  2015020068
# Getting data for game id =  2015020083
# Getting data for game id =  2015020097
# Getting data for game id =  2015020113
# Getting data for game id =  2015020128
# Getting data for game id =  2015020150
# Getting data for game id =  2015020160
# Getting data for game id =  2015020184
# Getting data for game id =  2015020193
# Getting data for game id =  2015020201
# Getting data for game id =  2015020222
# Getting data for game id =  2015020236
# Getting data for game id =  2015020251
# Getting data for game id =  2015020265
# Getting data for game id =  2015020285
# Getting data for game id =  2015020296
# Getting data for game id =  2015020313
# Getting data for game id =  2015020339
# Getting data for game id =  2015020354
# Getting data for game id =  2015020363
# Getting data for game id =  2015020378
# Getting data for game id =  2015020383
# Getting data for game id =  2015020400
# Getting data for game id =  2015020412
# Getting data for game id =  2015020423
# Getting data for game id =  2015020435
# Getting data for game id =  2015020454
# Getting data for game id =  2015020467
# Getting data for game id =  2015020479
# Getting data for game id =  2015020493
# Getting data for game id =  2015020511
# Getting data for game id =  2015020527
# Getting data for game id =  2015020545
# Getting data for game id =  2015020572
# Getting data for game id =  2015020580
# Getting data for game id =  2015020589
# Getting data for game id =  2015020602
# Getting data for game id =  2015020629
# Getting data for game id =  2015020632
# Getting data for game id =  2015020644
# Getting data for game id =  2015020672
# Getting data for game id =  2015020677
# Getting data for game id =  2015020707
# Getting data for game id =  2015020714
# Getting data for game id =  2015020736
# Getting data for game id =  2015020749
# Getting data for game id =  2015020764
# Getting data for game id =  2015020781
# Getting data for game id =  2015020793
# Getting data for game id =  2015020795
# Getting data for game id =  2015020823
# Getting data for game id =  2015020827
# Getting data for game id =  2015020842
# Getting data for game id =  2015020863
# Getting data for game id =  2015020877
# Getting data for game id =  2015020909
# Getting data for game id =  2015020923
# Getting data for game id =  2015020932
# Getting data for game id =  2015020949
# Getting data for game id =  2015020962
# Getting data for game id =  2015020978
# Getting data for game id =  2015020988
# Getting data for game id =  2015021010
# Getting data for game id =  2015021023
# Getting data for game id =  2015021033
# Getting data for game id =  2015021043
# Getting data for game id =  2015021056
# Getting data for game id =  2015021072
# Getting data for game id =  2015021086
# Getting data for game id =  2015021101
# Getting data for game id =  2015021122
# Getting data for game id =  2015021144
# Getting data for game id =  2015021157
# Getting data for game id =  2015021172
# Getting data for game id =  2015021185
# Getting data for game id =  2015021192
# Getting data for game id =  2015021208
# Getting data for game id =  2015021221
# Getting data for game id =  2015030111
# Getting data for game id =  2015030112
# Getting data for game id =  2015030113
# Getting data for game id =  2015030114
# Getting data for game id =  2015030115
# Getting data for game id =  2015030116
# Getting data for game id =  2016010018
# Getting data for game id =  2016010036
# Getting data for game id =  2016010060
# Getting data for game id =  2016010072
# Getting data for game id =  2016010099
# Getting data for game id =  2016020010
# Getting data for game id =  2016020020
# Getting data for game id =  2016020042
# Getting data for game id =  2016020056
# Getting data for game id =  2016020068
# Getting data for game id =  2016020086
# Getting data for game id =  2016020101
# Getting data for game id =  2016020113
# Getting data for game id =  2016020124
# Getting data for game id =  2016020136
# Getting data for game id =  2016020152
# Getting data for game id =  2016020168
# Getting data for game id =  2016020182
# Getting data for game id =  2016020202
# Getting data for game id =  2016020214
# Getting data for game id =  2016020234
# Getting data for game id =  2016020247
# Getting data for game id =  2016020265
# Getting data for game id =  2016020272
# Getting data for game id =  2016020286
# Getting data for game id =  2016020316
# Getting data for game id =  2016020324
# Getting data for game id =  2016020336
# Getting data for game id =  2016020350
# Getting data for game id =  2016020363
# Getting data for game id =  2016020378
# Getting data for game id =  2016020385
# Getting data for game id =  2016020400
# Getting data for game id =  2016020416
# Getting data for game id =  2016020438
# Getting data for game id =  2016020451
# Getting data for game id =  2016020457
# Getting data for game id =  2016020487
# Getting data for game id =  2016020501
# Getting data for game id =  2016020510
# Getting data for game id =  2016020527
# Getting data for game id =  2016020536
# Getting data for game id =  2016020554
# Getting data for game id =  2016020572
# Getting data for game id =  2016020585
# Getting data for game id =  2016020596
# Getting data for game id =  2016020609
# Getting data for game id =  2016020620
# Getting data for game id =  2016020636
# Getting data for game id =  2016020645
# Getting data for game id =  2016020669
# Getting data for game id =  2016020675
# Getting data for game id =  2016020690
# Getting data for game id =  2016020713
# Getting data for game id =  2016020734
# Getting data for game id =  2016020748
# Getting data for game id =  2016020768
# Getting data for game id =  2016020810
# Getting data for game id =  2016020818
# Getting data for game id =  2016020846
# Getting data for game id =  2016020857
# Getting data for game id =  2016020868
# Getting data for game id =  2016020880
# Getting data for game id =  2016020891
# Getting data for game id =  2016020901
# Getting data for game id =  2016020916
# Getting data for game id =  2016020927
# Getting data for game id =  2016020938
# Getting data for game id =  2016020955
# Getting data for game id =  2016020976
# Getting data for game id =  2016020997
# Getting data for game id =  2016021003
# Getting data for game id =  2016021029
# Getting data for game id =  2016021041
# Getting data for game id =  2016021049
# Getting data for game id =  2016021064
# Getting data for game id =  2016021081
# Getting data for game id =  2016021094
# Getting data for game id =  2016021109
# Getting data for game id =  2016021122
# Getting data for game id =  2016021131
# Getting data for game id =  2016021144
# Getting data for game id =  2016021157
# Getting data for game id =  2016021178
# Getting data for game id =  2016021199
# Getting data for game id =  2016021213
# Getting data for game id =  2016021228
# Getting data for game id =  2017010017
# Getting data for game id =  2017010059
# Getting data for game id =  2017010078
# Getting data for game id =  2017010092
# Getting data for game id =  2017010093
# Getting data for game id =  2017020014
# Getting data for game id =  2017020018
# Getting data for game id =  2017020052
# Getting data for game id =  2017020067
# Getting data for game id =  2017020083
# Getting data for game id =  2017020107
# Getting data for game id =  2017020116
# Getting data for game id =  2017020130
# Getting data for game id =  2017020145
# Getting data for game id =  2017020160
# Getting data for game id =  2017020174
# Getting data for game id =  2017020190
# Getting data for game id =  2017020203
# Getting data for game id =  2017020227
# Getting data for game id =  2017020242
# Getting data for game id =  2017020254
# Getting data for game id =  2017020269
# Getting data for game id =  2017020289
# Getting data for game id =  2017020296
# Getting data for game id =  2017020309
# Getting data for game id =  2017020321
# Getting data for game id =  2017020352
# Getting data for game id =  2017020362
# Getting data for game id =  2017020369
# Getting data for game id =  2017020392
# Getting data for game id =  2017020403
# Getting data for game id =  2017020413
# Getting data for game id =  2017020434
# Getting data for game id =  2017020448
# Getting data for game id =  2017020463
# Getting data for game id =  2017020473
# Getting data for game id =  2017020486
# Getting data for game id =  2017020510
# Getting data for game id =  2017020523
# Getting data for game id =  2017020540
# Getting data for game id =  2017020546
# Getting data for game id =  2017020571
# Getting data for game id =  2017020588
# Getting data for game id =  2017020608
# Getting data for game id =  2017020630
# Getting data for game id =  2017020647
# Getting data for game id =  2017020657
# Getting data for game id =  2017020666
# Getting data for game id =  2017020705
# Getting data for game id =  2017020716
# Getting data for game id =  2017020738
# Getting data for game id =  2017020752
# Getting data for game id =  2017020763
# Getting data for game id =  2017020777
# Getting data for game id =  2017020796
# Getting data for game id =  2017020818
# Getting data for game id =  2017020838
# Getting data for game id =  2017020862
# Getting data for game id =  2017020878
# Getting data for game id =  2017020903
# Getting data for game id =  2017020910
# Getting data for game id =  2017020918
# Getting data for game id =  2017020936
# Getting data for game id =  2017020951
# Getting data for game id =  2017020972
# Getting data for game id =  2017020985
# Getting data for game id =  2017020992
# Getting data for game id =  2017021008
# Getting data for game id =  2017021024
# Getting data for game id =  2017021038
# Getting data for game id =  2017021056
# Getting data for game id =  2017021067
# Getting data for game id =  2017021087
# Getting data for game id =  2017021099
# Getting data for game id =  2017021118
# Getting data for game id =  2017021125
# Getting data for game id =  2017021139
# Getting data for game id =  2017021156
# Getting data for game id =  2017021169
# Getting data for game id =  2017021186
# Getting data for game id =  2017021193
# Getting data for game id =  2017021206
# Getting data for game id =  2017021225
# Getting data for game id =  2017021234
# Getting data for game id =  2017021247
# Getting data for game id =  2017021261
# Getting data for game id =  2017020616
# Getting data for game id =  2018010005
# Getting data for game id =  2018010029
# Getting data for game id =  2018010055
# Getting data for game id =  2018010071
# Getting data for game id =  2018010085
# Getting data for game id =  2018010100
# Getting data for game id =  2018020019
# Getting data for game id =  2018020047
# Getting data for game id =  2018020064
# Getting data for game id =  2018020080
# Getting data for game id =  2018020099
# Getting data for game id =  2018020108
# Getting data for game id =  2018020122
# Getting data for game id =  2018020130
# Getting data for game id =  2018020148
# Getting data for game id =  2018020180
# Getting data for game id =  2018020192
# Getting data for game id =  2018020228
# Getting data for game id =  2018020248
# Getting data for game id =  2018020254
# Getting data for game id =  2018020267
# Getting data for game id =  2018020280
# Getting data for game id =  2018020296
# Getting data for game id =  2018020312
# Getting data for game id =  2018020325
# Getting data for game id =  2018020342
# Getting data for game id =  2018020351
# Getting data for game id =  2018020363
# Getting data for game id =  2018020378
# Getting data for game id =  2018020390
# Getting data for game id =  2018020399
# Getting data for game id =  2018020417
# Getting data for game id =  2018020430
# Getting data for game id =  2018020450
# Getting data for game id =  2018020470
# Getting data for game id =  2018020484
# Getting data for game id =  2018020497
# Getting data for game id =  2018020517
# Getting data for game id =  2018020531
# Getting data for game id =  2018020547
# Getting data for game id =  2018020562
# Getting data for game id =  2018020580
# Getting data for game id =  2018020591
# Getting data for game id =  2018020606
# Getting data for game id =  2018020623
# Getting data for game id =  2018020641
# Getting data for game id =  2018020660
# Getting data for game id =  2018020679
# Getting data for game id =  2018020685
# Getting data for game id =  2018020703
# Getting data for game id =  2018020714
# Getting data for game id =  2018020733
# Getting data for game id =  2018020747
# Getting data for game id =  2018020758
# Getting data for game id =  2018020782
# Getting data for game id =  2018020793
# Getting data for game id =  2018020811
# Getting data for game id =  2018020824
# Getting data for game id =  2018020848
# Getting data for game id =  2018020858
# Getting data for game id =  2018020865
# Getting data for game id =  2018020877
# Getting data for game id =  2018020908
# Getting data for game id =  2018020916
# Getting data for game id =  2018020930
# Getting data for game id =  2018020948
# Getting data for game id =  2018020966
# Getting data for game id =  2018020977
# Getting data for game id =  2018020989
# Getting data for game id =  2018021005
# Getting data for game id =  2018021013
# Getting data for game id =  2018021022
# Getting data for game id =  2018021033
# Getting data for game id =  2018021044
# Getting data for game id =  2018021060
# Getting data for game id =  2018021092
# Getting data for game id =  2018021101
# Getting data for game id =  2018021116
# Getting data for game id =  2018021130
# Getting data for game id =  2018021136
# Getting data for game id =  2018021156
# Getting data for game id =  2018021169
# Getting data for game id =  2018021180
# Getting data for game id =  2018021192
# Getting data for game id =  2018021204
# Getting data for game id =  2018021221
# Getting data for game id =  2018021244
# Getting data for game id =  2018021262
# Getting data for game id =  2019010002
# Getting data for game id =  2019010024
# Getting data for game id =  2019010034
# Getting data for game id =  2019010051
# Getting data for game id =  2019010067
# Getting data for game id =  2019010083
# Getting data for game id =  2019010097
# Getting data for game id =  2019020005
# Getting data for game id =  2019020021
# Getting data for game id =  2019020036
# Getting data for game id =  2019020058
# Getting data for game id =  2019020067
# Getting data for game id =  2019020080
# Getting data for game id =  2019020107
# Getting data for game id =  2019020121
# Getting data for game id =  2019020135
# Getting data for game id =  2019020153
# Getting data for game id =  2019020170
# Getting data for game id =  2019020178
# Getting data for game id =  2019020191
# Getting data for game id =  2019020208
# Getting data for game id =  2019020238
# Getting data for game id =  2019020252
# Getting data for game id =  2019020263
# Getting data for game id =  2019020272
# Getting data for game id =  2019020288
# Getting data for game id =  2019020306
# Getting data for game id =  2019020319
# Getting data for game id =  2019020334
# Getting data for game id =  2019020355
# Getting data for game id =  2019020362
# Getting data for game id =  2019020383
# Getting data for game id =  2019020408
# Getting data for game id =  2019020426
# Getting data for game id =  2019020457
# Getting data for game id =  2019020464
# Getting data for game id =  2019020473
# Getting data for game id =  2019020489
# Getting data for game id =  2019020508
# Getting data for game id =  2019020519
# Getting data for game id =  2019020548
# Getting data for game id =  2019020559
# Getting data for game id =  2019020572
# Getting data for game id =  2019020595
# Getting data for game id =  2019020608
# Getting data for game id =  2019020619
# Getting data for game id =  2019020632
# Getting data for game id =  2019020645
# Getting data for game id =  2019020654
# Getting data for game id =  2019020664
# Getting data for game id =  2019020681
# Getting data for game id =  2019020707
# Getting data for game id =  2019020729
# Getting data for game id =  2019020749
# Getting data for game id =  2019020760
# Getting data for game id =  2019020765
# Getting data for game id =  2019020794
# Getting data for game id =  2019020809
# Getting data for game id =  2019020818
# Getting data for game id =  2019020830
# Getting data for game id =  2019020847
# Getting data for game id =  2019020861
# Getting data for game id =  2019020868
# Getting data for game id =  2019020883
# Getting data for game id =  2019020898
# Getting data for game id =  2019020917
# Getting data for game id =  2019020931
# Getting data for game id =  2019020940
# Getting data for game id =  2019020957
# Getting data for game id =  2019020979
# Getting data for game id =  2019020987
# Getting data for game id =  2019021002
# Getting data for game id =  2019021012
# Getting data for game id =  2019021035
# Getting data for game id =  2019021054
# Getting data for game id =  2019021075
# Getting data for game id =  2019011004
# Getting data for game id =  2019030041
# Getting data for game id =  2019030042
# Getting data for game id =  2019030043
# Getting data for game id =  2019030044
# Getting data for game id =  2020020034
# Getting data for game id =  2020020049
# Getting data for game id =  2020020098
# Getting data for game id =  2020020114
# Getting data for game id =  2020020130
# Getting data for game id =  2020020139
# Getting data for game id =  2020020165
# Getting data for game id =  2020020176
# Getting data for game id =  2020020189
# Getting data for game id =  2020020203
# Getting data for game id =  2020020217
# Getting data for game id =  2020020232
# Getting data for game id =  2020020256
# Getting data for game id =  2020020062
# Getting data for game id =  2020020275
# Getting data for game id =  2020020292
# Getting data for game id =  2020020009
# Getting data for game id =  2020020303
# Getting data for game id =  2020020315
# Getting data for game id =  2020020330
# Getting data for game id =  2020020348
# Getting data for game id =  2020020368
# Getting data for game id =  2020020381
# Getting data for game id =  2020020076
# Getting data for game id =  2020020406
# Getting data for game id =  2020020420
# Getting data for game id =  2020020435
# Getting data for game id =  2020020449
# Getting data for game id =  2020020472
# Getting data for game id =  2020020487
# Getting data for game id =  2020020828
# Getting data for game id =  2020020505
# Getting data for game id =  2020020519
# Getting data for game id =  2020020538
# Getting data for game id =  2020020547
# Getting data for game id =  2020020560
# Getting data for game id =  2020020575
# Getting data for game id =  2020020590
# Getting data for game id =  2020020600
# Getting data for game id =  2020020615
# Getting data for game id =  2020020629
# Getting data for game id =  2020020648
# Getting data for game id =  2020020670
# Getting data for game id =  2020020679
# Getting data for game id =  2020020694
# Getting data for game id =  2020020707
# Getting data for game id =  2020020719
# Getting data for game id =  2020020732
# Getting data for game id =  2020020745
# Getting data for game id =  2020020758
# Getting data for game id =  2020020773
# Getting data for game id =  2020020787
# Getting data for game id =  2020020802
# Getting data for game id =  2020020020
# Getting data for game id =  2020020857
# Getting data for game id =  2020020841
# Getting data for game id =  2020030141
# Getting data for game id =  2020030142
# Getting data for game id =  2020030143
# Getting data for game id =  2020030144
# Getting data for game id =  2020030145
# Getting data for game id =  2020030146
# Getting data for game id =  2021010003
# Getting data for game id =  2021010027
# Getting data for game id =  2021010040
# Getting data for game id =  2021010071
# Getting data for game id =  2021010084
# Getting data for game id =  2021010095
# Getting data for game id =  2021020010
# Getting data for game id =  2021020025
# Getting data for game id =  2021020042
# Getting data for game id =  2021020055
# Getting data for game id =  2021020070
# Getting data for game id =  2021020085
# Getting data for game id =  2021020097
# Getting data for game id =  2021020111
# Getting data for game id =  2021020117
# Getting data for game id =  2021020152
# Getting data for game id =  2021020166
# Getting data for game id =  2021020180
# Getting data for game id =  2021020186
# Getting data for game id =  2021020200
# Getting data for game id =  2021020214
# Getting data for game id =  2021020233
# Getting data for game id =  2021020251
# Getting data for game id =  2021020265
# Getting data for game id =  2021020292
# Getting data for game id =  2021020309
# Getting data for game id =  2021020318
# Getting data for game id =  2021020338
# Getting data for game id =  2021020354
# Getting data for game id =  2021020370
# Getting data for game id =  2021020394
# Getting data for game id =  2021020416
# Getting data for game id =  2021020433
# Getting data for game id =  2021020440
# Getting data for game id =  2021020456
# Getting data for game id =  2021020544
# Getting data for game id =  2021020552
# Getting data for game id =  2021020568
# Getting data for game id =  2021020589
# Getting data for game id =  2021020605
# Getting data for game id =  2021020617
# Getting data for game id =  2021020638
# Getting data for game id =  2021020661
# Getting data for game id =  2021020669
# Getting data for game id =  2021020698
# Getting data for game id =  2021020709
# Getting data for game id =  2021020718
# Getting data for game id =  2021020736
# Getting data for game id =  2021020749
# Getting data for game id =  2021020760
# Getting data for game id =  2021020776
# Getting data for game id =  2021020793
# Getting data for game id =  2021020800
# Getting data for game id =  2021020527
# Getting data for game id =  2021020476
# Getting data for game id =  2021020498
# Getting data for game id =  2021020511
# Getting data for game id =  2021020816
# Getting data for game id =  2021020831
# Getting data for game id =  2021020865
# Getting data for game id =  2021020881
# Getting data for game id =  2021020899
# Getting data for game id =  2021020906
# Getting data for game id =  2021020920
# Getting data for game id =  2021020951
# Getting data for game id =  2021020963
# Getting data for game id =  2021020975
# Getting data for game id =  2021020981
# Getting data for game id =  2021021020
# Getting data for game id =  2021021036
# Getting data for game id =  2021021046
# Getting data for game id =  2021021061
# Getting data for game id =  2021021076
# Getting data for game id =  2021021092
# Getting data for game id =  2021021100
# Getting data for game id =  2021021116
# Getting data for game id =  2021021138
# Getting data for game id =  2021021148
# Getting data for game id =  2021021167
# Getting data for game id =  2021021194
# Getting data for game id =  2021021210
# Getting data for game id =  2021021223
# Getting data for game id =  2021021235
# Getting data for game id =  2021021253
# Getting data for game id =  2021021260
# Getting data for game id =  2021021272
# Getting data for game id =  2021021291
# Getting data for game id =  2021021300
# Getting data for game id =  2021030111
# Getting data for game id =  2021030112
# Getting data for game id =  2021030113
# Getting data for game id =  2021030114
# Getting data for game id =  2021030115
# Getting data for game id =  2021030116
# Getting data for game id =  2021030211
# Getting data for game id =  2021030212
# Getting data for game id =  2021030213
# Getting data for game id =  2021030214

# %% [markdown]
# ## SQL

# %% [markdown]
# ## Load the data we just created
#
# Now, we will run some sql queries on the data which we just created. First, let us load the data in three variables

# %%
panthers_players_boxscores = pd.read_csv("panthers_players_boxscores.csv")
panthers_game_boxscores = pd.read_csv("panthers_game_boxscores.csv")
panthers_players_table = pd.read_csv("panthers_players_table.csv")

# %%
pysqldf = lambda q: sqldf(q, globals())

# %% [markdown]
# ## Question.1
#
# Here, we are querying the panthers_players_boxscores and doing a group by on season and player_id and counting all the instances for each group by. This way, we will be able to look at all those players
# who had the most seasons.

# %%
q1 = '''
select season,
    player_id,
    count(*) as count from (select game_id,game_id/1000000 as season,player_id
    from panthers_players_boxscores) as p
group by p.season,p.player_id
order by count desc 
'''
q1_answer = pysqldf(q1)
print(q1_answer.head(20))
# Out:
#     season  player_id  count
# 0     2021  ID8476456     94
# 1     2021  ID8477346     94
# 2     2021  ID8477986     94
# 3     2021  ID8480185     93
# 4     2021  ID8477933     92
# 5     2015  ID8466285     91
# 6     2015  ID8469638     91
# 7     2015  ID8475191     91
# 8     2021  ID8475462     91
# 9     2021  ID8477409     90
# 10    2015  ID8448208     88
# 11    2015  ID8477932     87
# 12    2018  ID8471735     86
# 13    2018  ID8474884     86
# 14    2018  ID8476456     86
# 15    2021  ID8477407     86
# 16    2014  ID8466285     85
# 17    2015  ID8476456     85
# 18    2017  ID8471735     85
# 19    2017  ID8475760     85

# %% [markdown]
# ## Question.2
#
# We are querying the panthers_players_boxscores and ordering the data by skaterStats_plusMinus
# and only getting the top row with the maximum plus minus score.

# %%
q2 = '''
select game_id,skaterStats_plusMinus from panthers_players_boxscores
order by skaterStats_plusMinus desc
limit 1
'''
q2_answer = pysqldf(q2)
print(q2_answer)
# Out:
#       game_id  skaterStats_plusMinus
# 0  2021020661                    6.0

# %% [markdown]
# ## Question.3
#
# Here, we want to get the information on the youngest player from the latest season 2021-2022. We get the season by using teh where clause and then sort the data by age column.

# %%
q3 = '''
select id, age from panthers_players_table
where season = '20212022'
order by age
'''
q3_answer = pysqldf(q3)
print(q3_answer.head())
# Out:
#         id        age
# 0  8482113  19.342466
# 1  8481655  19.783562
# 2  8481519  19.800000
# 3  8480844  20.619178
# 4  8480015  21.972603

# %% [markdown]
# ## Question.4
#
# This is a complicated query. Let us try to understand this one by one.
#
# There is a sub query first.  Here, we are getting the max of penalty minutes from the panthers_players_boxscores and then in the main query, we are getting the player_id and game_id
# for which penality minutes was maximum.

# %%
q4 = '''
select player_id,game_id,skaterStats_penaltyMinutes 
from panthers_players_boxscores
where skaterStats_penaltyMinutes in (select max(skaterStats_penaltyMinutes) from panthers_players_boxscores)
'''
q4_answer = pysqldf(q4)
print(q4_answer)
# Out:
#    player_id     game_id  skaterStats_penaltyMinutes
# 0  ID8474230  2017020738                        39.0

# %% [markdown]
# ## Question.5
#
# We are extracting the game id from table panthers_game_boxscores and only getting he "Home"games with
# opponent goals = 0.

# %%
q5 = '''
select game_id
from panthers_game_boxscores
where HomeOrAway = 'home' and opponent_goals = 0
'''
q5_answer = pysqldf(q5)
print(q5_answer)
# Out:
#        game_id
# 0   2014010088
# 1   2014020037
# 2   2014020912
# 3   2014021172
# 4   2015020827
# 5   2016020596
# 6   2018010005
# 7   2018020865
# 8   2019021012
# 9   2019011004
# 10  2020020303
